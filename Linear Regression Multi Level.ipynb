# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from matplotlib import pyplot as plt
df = pd.read_csv('homeprices.csv')
mean1  =  df.bedrooms.mean()
df.bedrooms.fillna(mean1,inplace =True)
model = linear_model.LinearRegression()
model.fit(df.drop('price',axis=1),df.price)
pre = model.predict([[4100,6,8]])
pre
# Out:
# C:\Users\Sudip\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([793062.69844975])

# %%
#Exercise 
df = pd.read_csv('hiring.csv')
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# df.experience.fillna(0,inplace = True)
df['exp'] = le.fit_transform(df.experience) 
# print (df)
df = df.drop('experience',axis= 1)
ts = df['test_score(out of 10)']
ts.fillna(ts.mean(),inplace = True)
# print (df)
x = df.drop('salary($)',axis=1)
# print (x)
y = df['salary($)']
model = linear_model.LinearRegression()
model.fit(x,y)
# model.score(x,y)
pre = model.predict([[9,6,5]])

plt.plot(x,y)
plt.show()
# Out:
# C:\Users\Sudip\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
