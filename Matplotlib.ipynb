# %%
import matplotlib as mtl
import pandas as pd
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x = [1,3,5]
y = [5,6,4]
a = [1,3,7]
b = [6,8,9]
plt.plot(x,y, label = "First")
plt.plot(a,b, label = "Second")
plt.scatter(x,y, label = "First")
plt.scatter(a,b, label = "Second")
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.title("My Practice")
plt.legend()
plt.show()

# %%
frd = pd.read_csv("friends.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 frd = pd.read_csv("friends.csv")
# ----> 2 print (frd(axis = 0))
#
# TypeError: 'DataFrame' object is not callable

# %%
x = np.
